# %% [markdown]
# <a href="https://colab.research.google.com/github/fambargh/SAMPLE/blob/master/128.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#clone the repo executed in 10.108 s
# !git clone https://github.com/kbardool/keras-frcnn.git
# Out:
# Cloning into 'keras-frcnn'...
# remote: Enumerating objects: 589, done.
# remote: Total 589 (delta 0), reused 0 (delta 0), pack-reused 589
# Receiving objects: 100% (589/589), 173.38 KiB | 322.00 KiB/s, done.
# Resolving deltas: 100% (402/402), done.

# %%
cd keras-frcnn
# Out:
# [Errno 2] No such file or directory: 'keras-frcnn'
# /content/keras-frcnn

# %%
# !pip install -r requirements.txt
# Out:
# ...
#      |████████████████████████████████| 204kB 2.3MB/s
# ...
#   Created wheel for Keras: filename=Keras-2.0.3-cp36-none-any.whl size=232964 sha256=02998ff0249ace32cf1d3bf7e269643cdd7c87a28d7abebce906b7e040e0483f
#   Stored in directory: /root/.cache/pip/wheels/a6/fb/de/faea9e49d563a35f198c6dede7f9260074b5beb8f9bffaaaa1
# Successfully built Keras
# ERROR: textgenrnn 1.4.1 has requirement keras>=2.1.5, but you'll have keras 2.0.3 which is incompatible.
# ...
#   Found existing installation: Keras 2.2.5
#     Uninstalling Keras-2.2.5:
#       Successfully uninstalled Keras-2.2.5
# ...

# %%
from google.colab import files
files.upload()

# %%
from google.colab import files
files.upload()

# %%
rm -rf test_frcnn.py

# %%
from google.colab import files
files.upload()

# %%
from zipfile import ZipFile
filename = "500.zip"

with ZipFile(filename,'r') as zip:
  zip.extractall()
  print('Done')
# Out:
# Done

# %%
from google.colab import files
files.upload()

# %%
from zipfile import ZipFile
filename = "resault1.zip"

with ZipFile(filename,'r') as zip:
  zip.extractall()
  print('Done')
# Out:
# Done

# %%
from google.colab import files
files.upload()

# %%
from zipfile import ZipFile
filename = "resault2.zip"

with ZipFile(filename,'r') as zip:
  zip.extractall()
  print('Done')
# Out:
# Done

# %%
# test process executed in 35.301 s
# !python test_frcnn1.py -p 128
# Out:
# Using TensorFlow backend.
# {0: 'od', 1: 'bg'}
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:47: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:351: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:3176: The name tf.random_uniform is deprecated. Please use tf.random.uniform instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:3043: The name tf.nn.max_pool is deprecated. Please use tf.nn.max_pool2d instead.
#
# ...

# %%
# !zip -r /content/keras-frcnn/resault12.zip /content/keras-frcnn/resault1
# Out:
#   adding: content/keras-frcnn/resault1/ (stored 0%)
#   adding: content/keras-frcnn/resault1/Im0521_g_ORIGA.png (deflated 2%)
#   adding: content/keras-frcnn/resault1/Im0494_g_ORIGA.png (deflated 2%)
#   adding: content/keras-frcnn/resault1/Im0484_g_ORIGA.png (deflated 2%)
#   adding: content/keras-frcnn/resault1/Im0563_g_ORIGA.png (deflated 3%)
#   adding: content/keras-frcnn/resault1/Im0554_g_ORIGA.png (deflated 1%)
#   adding: content/keras-frcnn/resault1/Im0507_g_ORIGA.png (deflated 2%)
#   adding: content/keras-frcnn/resault1/Im0627_g_ORIGA.png (deflated 2%)
#   adding: content/keras-frcnn/resault1/Im0594_g_ORIGA.png (deflated 4%)
#   adding: content/keras-frcnn/resault1/Im0537_g_ORIGA.png (deflated 3%)
#   adding: content/keras-frcnn/resault1/Im0564_g_ORIGA.png (deflated 2%)
#   adding: content/keras-frcnn/resault1/Im0535_g_ORIGA.png (deflated 2%)
#   adding: content/keras-frcnn/resault1/Im0650_g_ORIGA.png (deflated 2%)
# ...

# %%
cd /content/keras-frcnn
# Out:
# /content/keras-frcnn

# %%
files.download("resault12.zip")
# Out:
# ----------------------------------------
# Exception happened during processing of request from ('::ffff:127.0.0.1', 51370, 0, 0)
# Traceback (most recent call last):
#   File "/usr/lib/python3.6/socketserver.py", line 320, in _handle_request_noblock
#     self.process_request(request, client_address)
#   File "/usr/lib/python3.6/socketserver.py", line 351, in process_request
#     self.finish_request(request, client_address)
#   File "/usr/lib/python3.6/socketserver.py", line 364, in finish_request
#     self.RequestHandlerClass(request, client_address, self)
#   File "/usr/lib/python3.6/socketserver.py", line 724, in __init__
#     self.handle()
#   File "/usr/lib/python3.6/http/server.py", line 418, in handle
#     self.handle_one_request()
#   File "/usr/lib/python3.6/http/server.py", line 406, in handle_one_request
#     method()
#   File "/usr/lib/python3.6/http/server.py", line 639, in do_GET
#     self.copyfile(f, self.wfile)
# ...

# %%
# !zip -r /content/keras-frcnn/resault22.zip /content/keras-frcnn/resault2
# Out:
#   adding: content/keras-frcnn/resault2/ (stored 0%)
#   adding: content/keras-frcnn/resault2/Im0521_g_ORIGA.png (deflated 1%)
#   adding: content/keras-frcnn/resault2/Im0494_g_ORIGA.png (deflated 1%)
#   adding: content/keras-frcnn/resault2/Im0484_g_ORIGA.png (deflated 1%)
#   adding: content/keras-frcnn/resault2/Im0563_g_ORIGA.png (deflated 1%)
#   adding: content/keras-frcnn/resault2/Im0554_g_ORIGA.png (deflated 0%)
#   adding: content/keras-frcnn/resault2/Im0507_g_ORIGA.png (deflated 1%)
#   adding: content/keras-frcnn/resault2/Im0627_g_ORIGA.png (deflated 1%)
#   adding: content/keras-frcnn/resault2/Im0594_g_ORIGA.png (deflated 3%)
#   adding: content/keras-frcnn/resault2/Im0537_g_ORIGA.png (deflated 1%)
#   adding: content/keras-frcnn/resault2/Im0564_g_ORIGA.png (deflated 1%)
#   adding: content/keras-frcnn/resault2/Im0535_g_ORIGA.png (deflated 1%)
#   adding: content/keras-frcnn/resault2/Im0650_g_ORIGA.png (deflated 1%)
# ...

# %%
files.download("resault21.zip")
