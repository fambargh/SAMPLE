# %% [markdown]
# <a href="https://colab.research.google.com/github/fambargh/SAMPLE/blob/master/128_for_all_image_crop.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#clone the repo executed in 10.108 s
# !git clone https://github.com/kbardool/keras-frcnn.git
# Out:
# Cloning into 'keras-frcnn'...
# remote: Enumerating objects: 589, done.
# remote: Total 589 (delta 0), reused 0 (delta 0), pack-reused 589
# Receiving objects: 100% (589/589), 173.38 KiB | 853.00 KiB/s, done.
# Resolving deltas: 100% (402/402), done.

# %%
#generate the path for work
cd keras-frcnn
# Out:
# /content/keras-frcnn

# %%
# !ls
# Out:
# keras_frcnn  measure_map.py  requirements.txt  train_frcnn.py
# LICENSE      README.md	     test_frcnn.py

# %%
#first upload train.csv file then upload train.zip and unzip it and finally upload train_frcnn.py 
#after removing preveuos version named train_frcnn.py...
from google.colab import files
files.upload()

# %%
from google.colab import files
files.upload()

# %%
from zipfile import ZipFile
filename = "train128.zip"

with ZipFile(filename,'r') as zip:
  zip.extractall()
  print('Done')
# Out:
# Done

# %%
# !rm -rf train_frcnn.py

# %%
# !rm -rf train128.zip

# %%
# !ls
# Out:
# keras_frcnn  measure_map.py  requirements.txt  train128
# LICENSE      README.md	     test_frcnn.py     train.csv

# %%
from google.colab import files
files.upload()

# %%
# !pip install -r requirements.txt
# Out:
# ...
#      |████████████████████████████████| 204kB 6.4MB/s
# ...
#   Created wheel for Keras: filename=Keras-2.0.3-cp36-none-any.whl size=232964 sha256=914a4c50dcf1823937bf8642e0729087e6bda59f9b1e924c25489dc64b024ed5
#   Stored in directory: /root/.cache/pip/wheels/a6/fb/de/faea9e49d563a35f198c6dede7f9260074b5beb8f9bffaaaa1
# Successfully built Keras
# ERROR: textgenrnn 1.4.1 has requirement keras>=2.1.5, but you'll have keras 2.0.3 which is incompatible.
# ...
#   Found existing installation: Keras 2.2.5
#     Uninstalling Keras-2.2.5:
#       Successfully uninstalled Keras-2.2.5
# ...

# %%
cd /content/keras-frcnn
# Out:
# /content/keras-frcnn

# %%
# !pwd
# Out:
# /content/keras-frcnn

# %%
cd /content/keras-frcnn
# Out:
# /content/keras-frcnn

# %%
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
from matplotlib import patches

# %%
train = pd.read_csv('/content/keras-frcnn/train.csv')
train.head()
# Out:
#   image_names cell_type  xmin  xmax  ymin  ymax
# 0    01_g.png        od    90   111    47    73
# 1    01_h.png        od    82   111    59    99
# 2    02_g.png        od    20    42    48    76
# 3    02_h.png        od    21    50    56    91
# 4    03_g.png        od    83   107    48    80

# %%
data = pd.DataFrame()
data['format'] = train['image_names']

# as the images are in train_images folder, add train_images before the image name
for i in range(data.shape[0]):
    data['format'][i] = '/content/keras-frcnn/train128/' + data['format'][i]

# add xmin, ymin, xmax, ymax and class as per the format required
for i in range(data.shape[0]):
    data['format'][i] = data['format'][i] + ',' + str(train['xmin'][i]) + ',' + str(train['ymin'][i]) + ',' + str(train['xmax'][i]) + ',' + str(train['ymax'][i]) + ',' + train['cell_type'][i]

data.to_csv('annotate.txt', header=None, index=None, sep=' ')

# %%
cd /content/keras-frcnn
# Out:
# /content/keras-frcnn

# %%
 # !python train_frcnn.py -o simple -p 'annotate.txt'
# Out:
# Using TensorFlow backend.
# Parsing annotation files
# Training images per class:
# {'bg': 0, 'od': 510}
# Num classes (including bg) = 2
# Config has been written to config.pickle, and can be loaded when testing to ensure correct results
# Num train samples 414
# Num val samples 96
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:47: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:351: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:3176: The name tf.random_uniform is deprecated. Please use tf.random.uniform instead.
#
# ...

# %%
rm -rf test_frcnn.py

# %%
from google.colab import files
files.upload()

# %%
from google.colab import files
files.upload()

# %%
from zipfile import ZipFile
filename = "test128.zip"

with ZipFile(filename,'r') as zip:
  zip.extractall()
  print('Done')
# Out:
# Done

# %%
rm -rf resault1

# %%
rm -rf resault1.zip

# %%
rm -rf resault2

# %%
rm -rf resault2.zip

# %%
from google.colab import files
files.upload()

# %%
from zipfile import ZipFile
filename = "resault1.zip"

with ZipFile(filename,'r') as zip:
  zip.extractall()
  print('Done')
# Out:
# Done

# %%
from google.colab import files
files.upload()

# %%
from zipfile import ZipFile
filename = "resault2.zip"

with ZipFile(filename,'r') as zip:
  zip.extractall()
  print('Done')
# Out:
# Done

# %%
# test process executed in 35.301 s
# !python test_frcnn1.py -p test128
# Out:
# Using TensorFlow backend.
# {0: 'od', 1: 'bg'}
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:47: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:351: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:3176: The name tf.random_uniform is deprecated. Please use tf.random.uniform instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:3043: The name tf.nn.max_pool is deprecated. Please use tf.nn.max_pool2d instead.
#
# ...

# %%
# !zip -r /content/keras-frcnn/test128test1.zip /content/keras-frcnn/resault1
# Out:
#   adding: content/keras-frcnn/resault1/ (stored 0%)
#   adding: content/keras-frcnn/resault1/Im0521_g_ORIGA.png (deflated 0%)
#   adding: content/keras-frcnn/resault1/Im0494_g_ORIGA.png (deflated 0%)
#   adding: content/keras-frcnn/resault1/Im0484_g_ORIGA.png (deflated 1%)
#   adding: content/keras-frcnn/resault1/Im0563_g_ORIGA.png (deflated 1%)
#   adding: content/keras-frcnn/resault1/Im0554_g_ORIGA.png (deflated 0%)
#   adding: content/keras-frcnn/resault1/Im0507_g_ORIGA.png (deflated 1%)
#   adding: content/keras-frcnn/resault1/drishtiGS_065.png (deflated 0%)
#   adding: content/keras-frcnn/resault1/Im0627_g_ORIGA.png (deflated 0%)
#   adding: content/keras-frcnn/resault1/Im0594_g_ORIGA.png (deflated 1%)
#   adding: content/keras-frcnn/resault1/Im0537_g_ORIGA.png (deflated 1%)
#   adding: content/keras-frcnn/resault1/Im0564_g_ORIGA.png (deflated 1%)
#   adding: content/keras-frcnn/resault1/drishtiGS_097.png (deflated 0%)
# ...

# %%
# !zip -r /content/keras-frcnn/test128test2.zip /content/keras-frcnn/resault2
# Out:
#   adding: content/keras-frcnn/resault2/ (stored 0%)
#   adding: content/keras-frcnn/resault2/Im0521_g_ORIGA.png (deflated 0%)
#   adding: content/keras-frcnn/resault2/Im0494_g_ORIGA.png (deflated 0%)
#   adding: content/keras-frcnn/resault2/Im0484_g_ORIGA.png (deflated 1%)
#   adding: content/keras-frcnn/resault2/Im0563_g_ORIGA.png (deflated 0%)
#   adding: content/keras-frcnn/resault2/Im0554_g_ORIGA.png (deflated 1%)
#   adding: content/keras-frcnn/resault2/Im0507_g_ORIGA.png (deflated 0%)
#   adding: content/keras-frcnn/resault2/drishtiGS_065.png (stored 0%)
#   adding: content/keras-frcnn/resault2/Im0627_g_ORIGA.png (deflated 1%)
#   adding: content/keras-frcnn/resault2/Im0594_g_ORIGA.png (deflated 0%)
#   adding: content/keras-frcnn/resault2/Im0537_g_ORIGA.png (deflated 0%)
#   adding: content/keras-frcnn/resault2/Im0564_g_ORIGA.png (deflated 0%)
#   adding: content/keras-frcnn/resault2/drishtiGS_097.png (deflated 1%)
# ...
