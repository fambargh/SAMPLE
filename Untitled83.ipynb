# %% [markdown]
# <a href="https://colab.research.google.com/github/fambargh/SAMPLE/blob/master/Untitled83.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
! pip install keras==2.0.3
# Out:
# Collecting keras==2.0.3
#   Downloading https://files.pythonhosted.org/packages/1b/36/fc4b247ec139ad9cc6f223ed10729d85401fc5203703c23457794f9bfe60/Keras-2.0.3.tar.gz (196kB)
#      |████████████████████████████████| 204kB 3.3MB/s
# Requirement already satisfied: theano in /usr/local/lib/python3.6/dist-packages (from keras==2.0.3) (1.0.4)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.6/dist-packages (from keras==2.0.3) (3.13)
# Requirement already satisfied: six in /usr/local/lib/python3.6/dist-packages (from keras==2.0.3) (1.12.0)
# Requirement already satisfied: numpy>=1.9.1 in /usr/local/lib/python3.6/dist-packages (from theano->keras==2.0.3) (1.17.3)
# Requirement already satisfied: scipy>=0.14 in /usr/local/lib/python3.6/dist-packages (from theano->keras==2.0.3) (1.3.1)
# Building wheels for collected packages: keras
#   Building wheel for keras (setup.py) ... done
#   Created wheel for keras: filename=Keras-2.0.3-cp36-none-any.whl size=232964 sha256=c494ab0febadccd4241ef790e41fa31d3adf13ad3fab785be73ee6b30a4dfeb7
#   Stored in directory: /root/.cache/pip/wheels/a6/fb/de/faea9e49d563a35f198c6dede7f9260074b5beb8f9bffaaaa1
# Successfully built keras
# ERROR: textgenrnn 1.4.1 has requirement keras>=2.1.5, but you'll have keras 2.0.3 which is incompatible.
# Installing collected packages: keras
#   Found existing installation: Keras 2.2.5
#     Uninstalling Keras-2.2.5:
#       Successfully uninstalled Keras-2.2.5
# Successfully installed keras-2.0.3

# %%
! pip install h5py
# Out:
# Requirement already satisfied: h5py in /usr/local/lib/python3.6/dist-packages (2.8.0)
# Requirement already satisfied: six in /usr/local/lib/python3.6/dist-packages (from h5py) (1.12.0)
# Requirement already satisfied: numpy>=1.7 in /usr/local/lib/python3.6/dist-packages (from h5py) (1.17.3)

# %%
from google.colab import files
files.upload()
# Out:
#      <input type="file" id="files-e1812b22-70f1-405b-92c3-5fa2081b51fe" name="files[]" multiple disabled />
#      <output id="result-e1812b22-70f1-405b-92c3-5fa2081b51fe">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving train.csv to train.csv
# {'train.csv': b'image_names,cell_type,xmin,xmax,ymin,ymax\r\nBloodImage_00111.jpg,RBC,458,571,198,296\r\nBloodImage_00111.jpg,RBC,405,518,240,338\r\nBloodImage_00111.jpg,RBC,365,478,40,138\r\nBloodImage_00111.jpg,RBC,512,630,75,188\r\nBloodImage_00111.jpg,RBC,468,570,71,175\r\nBloodImage_00111.jpg,RBC,175,288,169,267\r\nBloodImage_00111.jpg,RBC,278,391,358,456\r\nBloodImage_00111.jpg,RBC,527,640,306,404\r\nBloodImage_00111.jpg,RBC,229,342,31,129\r\nBloodImage_00111.jpg,RBC,23,136,44,142\r\nBloodImage_00111.jpg,RBC,21,134,310,408\r\nBloodImage_00111.jpg,RBC,121,234,280,378\r\nBloodImage_00111.jpg,RBC,60,143,382,480\r\nBloodImage_00111.jpg,RBC,50,194,134,254\r\nBloodImage_00111.jpg,RBC,399,495,405,480\r\nBloodImage_00111.jpg,WBC,142,258,378,480\r\nBloodImage_00111.jpg,Platelets,360,395,85,115\r\nBloodImage_00112.jpg,RBC,178,278,350,438\r\nBloodImage_00112.jpg,RBC,162,262,141,229\r\nBloodImage_00112.jpg,RBC,205,314,30,143\r\nBloodImage_00112.jpg,RBC,95,198,1,81\r\nBloodImage_00112.jpg,RBC,287,389,260,367\r\nBloodImage_00112.jpg,RBC,448,550,128,235\r\nBloodImage_00112.jpg,RBC,430,525,243,337\r\nBloodImage_00112.jpg,RBC,423,518,385,480\r\nBloodImage_00112.jpg,RBC,369,434,18,87\r\nBloodImage_00112.jpg,RBC,2,98,57,137\r\nBloodImage_00112.jpg,RBC,353,454,123,224\r\nBloodImage_00112.jpg,RBC,22,122,154,242\r\nBloodImage_00112.jpg,WBC,1,161,264,414\r\nBloodImage_00112.jpg,Platelets,533,580,108,151\r\nBloodImage_00112.jpg,RBC,79,180,168,279\r\nBloodImage_00113.jpg,RBC,262,366,151,245\r\nBloodImage_00113.jpg,RBC,169,273,23,117\r\nBloodImage_00113.jpg,RBC,496,584,178,248
zip"

with ZipFile(filename,'r') as zip:
  zip.extractall()
  print('Done')
# Out:
# Done

# %%
# !git clone https://github.com/kbardool/keras-frcnn.git
# Out:
# Cloning into 'keras-frcnn'...
# remote: Enumerating objects: 589, done.
# remote: Total 589 (delta 0), reused 0 (delta 0), pack-reused 589
# Receiving objects: 100% (589/589), 173.38 KiB | 2.38 MiB/s, done.
# Resolving deltas: 100% (402/402), done.

# %%
cd keras-frcnn
# Out:
# /content/keras-frcnn

# %%
# !ls
# Out:
# keras_frcnn  measure_map.py  requirements.txt  train.csv       train_images
# LICENSE      README.md	     test_frcnn.py     train_frcnn.py  train_images.zip

# %%
cd keras-frcnn

# %%
# !pip install -r requirements.txt
# Out:
# Requirement already satisfied: h5py in /usr/local/lib/python3.6/dist-packages (from -r requirements.txt (line 1)) (2.8.0)
# Requirement already satisfied: Keras==2.0.3 in /usr/local/lib/python3.6/dist-packages (from -r requirements.txt (line 2)) (2.0.3)
# Requirement already satisfied: numpy in /usr/local/lib/python3.6/dist-packages (from -r requirements.txt (line 3)) (1.17.3)
# Requirement already satisfied: opencv-python in /usr/local/lib/python3.6/dist-packages (from -r requirements.txt (line 4)) (3.4.7.28)
# Requirement already satisfied: sklearn in /usr/local/lib/python3.6/dist-packages (from -r requirements.txt (line 5)) (0.0)
# Requirement already satisfied: six in /usr/local/lib/python3.6/dist-packages (from h5py->-r requirements.txt (line 1)) (1.12.0)
# Requirement already satisfied: theano in /usr/local/lib/python3.6/dist-packages (from Keras==2.0.3->-r requirements.txt (line 2)) (1.0.4)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.6/dist-packages (from Keras==2.0.3->-r requirements.txt (line 2)) (3.13)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.6/dist-packages (from sklearn->-r requirements.txt (line 5)) (0.21.3)
# Requirement already satisfied: scipy>=0.14 in /usr/local/lib/python3.6/dist-packages (from theano->Keras==2.0.3->-r requirements.txt (line 2)) (1.3.1)
# Requirement already satisfied: joblib>=0.11 in /usr/local/lib/python3.6/dist-packages (from scikit-learn->sklearn->-r requirements.txt (line 5)) (0.14.0)

# %%
cd /content/keras-frcnn
# Out:
# /content/keras-frcnn

# %%
# !pwd
# Out:
# /content/keras-frcnn

# %%
cd /content/keras-frcnn

# %%
# importing required libraries
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
from matplotlib import patches

# %%
train = pd.read_csv('/content/keras-frcnn/train.csv')
train.head()
# Out:
#             image_names cell_type  xmin  xmax  ymin  ymax
# 0  BloodImage_00111.jpg       RBC   458   571   198   296
# 1  BloodImage_00111.jpg       RBC   405   518   240   338
# 2  BloodImage_00111.jpg       RBC   365   478    40   138
# 3  BloodImage_00111.jpg       RBC   512   630    75   188
# 4  BloodImage_00111.jpg       RBC   468   570    71   175

# %%
data = pd.DataFrame()
data['format'] = train['image_names']

# as the images are in train_images folder, add train_images before the image name
for i in range(data.shape[0]):
    data['format'][i] = '/content/keras-frcnn/train_images/' + data['format'][i]

# add xmin, ymin, xmax, ymax and class as per the format required
for i in range(data.shape[0]):
    data['format'][i] = data['format'][i] + ',' + str(train['xmin'][i]) + ',' + str(train['ymin'][i]) + ',' + str(train['xmax'][i]) + ',' + str(train['ymax'][i]) + ',' + train['cell_type'][i]

data.to_csv('annotate.txt', header=None, index=None, sep=' ')

# %%
cd /content/keras-frcnn
# Out:
# /content/keras-frcnn

# %%
# !python train_frcnn.py -o simple -p 'annotate.txt'
# Out:
# Using TensorFlow backend.
# Parsing annotation files
# Training images per class:
# {'Platelets': 233, 'RBC': 2749, 'WBC': 265, 'bg': 0}
# Num classes (including bg) = 4
# Config has been written to config.pickle, and can be loaded when testing to ensure correct results
# Num train samples 223
# Num val samples 41
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:47: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:351: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:3176: The name tf.random_uniform is deprecated. Please use tf.random.uniform instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:3043: The name tf.nn.max_pool is deprecated. Please use tf.nn.max_pool2d instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:3153: The name tf.random_normal is deprecated. Please use tf.random.normal instead.
#
# WARNING:tensorflow:From /content/keras-frcnn/keras_frcnn/RoiPoolingConv.py:105: The name tf.image.resize_images is deprecated. Please use tf.image.resize instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:3045: The name tf.nn.avg_pool is deprecated. Please use tf.nn.avg_pool2d instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:1064: calling reduce_prod_v1 (from tensorflow.python.ops.math_ops) with keep_dims is deprecated and will be removed in a future version.
# Instructions for updating:
# keep_dims is deprecated, use keepdims instead
# loading weights from resnet50_weights_tf_dim_ordering_tf_kernels.h5
# Could not load pretrained model weights. Weights can be found in the keras application folder 		https://github.com/fchollet/keras/tree/master/keras/applications
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/optimizers.py:675: The name tf.train.Optimizer is deprecated. Please use tf.compat.v1.train.Optimizer instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:2642: The name tf.log is deprecated. Please use tf.math.log instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow_core/python/ops/nn_impl.py:183: where (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:1046: calling reduce_sum_v1 (from tensorflow.python.ops.math_ops) with keep_dims is deprecated and will be removed in a future version.
# Instructions for updating:
# keep_dims is deprecated, use keepdims instead
# Starting training
# Epoch 1/2000
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:768: The name tf.assign_add is deprecated. Please use tf.compat.v1.assign_add instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:521: calling Constant.__init__ (from tensorflow.python.ops.init_ops) with dtype is deprecated and will be removed in a future version.
# Instructions for updating:
# Call initializer instance with the dtype argument instead of passing it to the constructor
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:764: The name tf.assign is deprecated. Please use tf.compat.v1.assign instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:141: The name tf.get_default_session is deprecated. Please use tf.compat.v1.get_default_session instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:146: The name tf.ConfigProto is deprecated. Please use tf.compat.v1.ConfigProto instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:151: The name tf.Session is deprecated. Please use tf.compat.v1.Session instead.
#
# 2019-11-11 20:52:23.583442: I tensorflow/core/platform/profile_utils/cpu_utils.cc:94] CPU Frequency: 2300000000 Hz
# 2019-11-11 20:52:23.583707: I tensorflow/compiler/xla/service/service.cc:168] XLA service 0x31bf2c0 initialized for platform Host (this does not guarantee that XLA will be used). Devices:
# 2019-11-11 20:52:23.583743: I tensorflow/compiler/xla/service/service.cc:176]   StreamExecutor device (0): Host, Default Version
# 2019-11-11 20:52:23.590006: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcuda.so.1
# 2019-11-11 20:52:23.757540: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2019-11-11 20:52:23.758607: I tensorflow/compiler/xla/service/service.cc:168] XLA service 0x31bf100 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# 2019-11-11 20:52:23.758663: I tensorflow/compiler/xla/service/service.cc:176]   StreamExecutor device (0): Tesla K80, Compute Capability 3.7
# 2019-11-11 20:52:23.760129: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2019-11-11 20:52:23.760942: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1618] Found device 0 with properties:
# name: Tesla K80 major: 3 minor: 7 memoryClockRate(GHz): 0.8235
# pciBusID: 0000:00:04.0
# 2019-11-11 20:52:23.779001: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudart.so.10.0
# 2019-11-11 20:52:23.985264: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcublas.so.10.0
# 2019-11-11 20:52:24.094401: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcufft.so.10.0
# 2019-11-11 20:52:24.129219: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcurand.so.10.0
# 2019-11-11 20:52:24.379929: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcusolver.so.10.0
# 2019-11-11 20:52:24.527315: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcusparse.so.10.0
# 2019-11-11 20:52:24.983592: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudnn.so.7
# 2019-11-11 20:52:24.983908: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2019-11-11 20:52:24.984796: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2019-11-11 20:52:24.985478: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1746] Adding visible gpu devices: 0
# 2019-11-11 20:52:24.990803: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudart.so.10.0
# 2019-11-11 20:52:24.992637: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1159] Device interconnect StreamExecutor with strength 1 edge matrix:
# 2019-11-11 20:52:24.992675: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1165]      0
# 2019-11-11 20:52:24.992692: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1178] 0:   N
# 2019-11-11 20:52:24.993937: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2019-11-11 20:52:24.994844: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2019-11-11 20:52:24.995612: W tensorflow/core/common_runtime/gpu/gpu_bfc_allocator.cc:39] Overriding allow_growth setting because the TF_FORCE_GPU_ALLOW_GROWTH environment variable is set. Original config value was 0.
# 2019-11-11 20:52:24.995675: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1304] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 10805 MB memory) -> physical GPU (device: 0, name: Tesla K80, pci bus id: 0000:00:04.0, compute capability: 3.7)
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:300: The name tf.global_variables is deprecated. Please use tf.compat.v1.global_variables instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:308: The name tf.variables_initializer is deprecated. Please use tf.compat.v1.variables_initializer instead.
#
# 2019-11-11 20:52:32.722029: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudnn.so.7
# 2019-11-11 20:52:35.287046: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcublas.so.10.0
# 1000/1000 [==============================] - 1785s - rpn_cls: 0.2215 - rpn_regr: 0.1072 - detector_cls: 0.5111 - detector_regr: 0.2562
# Mean number of bounding boxes from RPN overlapping ground truth boxes: 61.794
# Classifier accuracy for bounding boxes from RPN: 0.75125
# Loss RPN classifier: 0.22149044171827517
# Loss RPN regression: 0.10719220824353397
# Loss Detector classifier: 0.5111042621433735
# Loss Detector regression: 0.2562063539624214
# Elapsed time: 1785.6637675762177
# Total loss decreased from inf to 1.095993266067604, saving weights
# Epoch 2/2000
# Average number of overlapping bounding boxes from RPN = 61.794 for 1000 previous iterations
# 1000/1000 [==============================] - 1758s - rpn_cls: 0.0955 - rpn_regr: 0.0910 - detector_cls: 0.4040 - detector_regr: 0.1963
# Mean number of bounding boxes from RPN overlapping ground truth boxes: 67.968
# Classifier accuracy for bounding boxes from RPN: 0.815375
# Loss RPN classifier: 0.09546555608545895
# Loss RPN regression: 0.0910322758704424
# Loss Detector classifier: 0.4039964260607958
# Loss Detector regression: 0.19627458569779993
# Elapsed time: 1790.0007739067078
# Total loss decreased from 1.095993266067604 to 0.7867688437144971, saving weights
# Epoch 3/2000
# Average number of overlapping bounding boxes from RPN = 67.968 for 1000 previous iterations
# 1000/1000 [==============================] - 1759s - rpn_cls: 0.0780 - rpn_regr: 0.0744 - detector_cls: 0.3611 - detector_regr: 0.1637
# Mean number of bounding boxes from RPN overlapping ground truth boxes: 70.746
# Classifier accuracy for bounding boxes from RPN: 0.83828125
# Loss RPN classifier: 0.07802478485832308
# Loss RPN regression: 0.0744008098298218
# Loss Detector classifier: 0.36105693243443965
# Loss Detector regression: 0.16366689532250167
# Elapsed time: 1759.982344865799
# Total loss decreased from 0.7867688437144971 to 0.6771494224450861, saving weights
# Epoch 4/2000
# Average number of overlapping bounding boxes from RPN = 70.746 for 1000 previous iterations
# 1000/1000 [==============================] - 1761s - rpn_cls: 0.0614 - rpn_regr: 0.0672 - detector_cls: 0.3384 - detector_regr: 0.1385
# Mean number of bounding boxes from RPN overlapping ground truth boxes: 73.087
# Classifier accuracy for bounding boxes from RPN: 0.84696875
# Loss RPN classifier: 0.061414017164300276
# Loss RPN regression: 0.06715656834817492
# Loss Detector classifier: 0.33835241302102803
# Loss Detector regression: 0.1385006459634751
# Elapsed time: 1762.239179134369
# Total loss decreased from 0.6771494224450861 to 0.6054236444969783, saving weights
# Epoch 5/2000
# Average number of overlapping bounding boxes from RPN = 73.087 for 1000 previous iterations
# 1000/1000 [==============================] - 1764s - rpn_cls: 0.0505 - rpn_regr: 0.0594 - detector_cls: 0.3278 - detector_regr: 0.1234
# Mean number of bounding boxes from RPN overlapping ground truth boxes: 72.355
# Classifier accuracy for bounding boxes from RPN: 0.8544375
# Loss RPN classifier: 0.05054307448094187
# Loss RPN regression: 0.059438710381975395
# Loss Detector classifier: 0.3277514461800456
# Loss Detector regression: 0.123446184406057
# Elapsed time: 1764.8693313598633
# Total loss decreased from 0.6054236444969783 to 0.5611794154490198, saving weights
# Epoch 6/2000
# Average number of overlapping bounding boxes from RPN = 72.355 for 1000 previous iterations
#   54/1000 [>.............................] - ETA: 1684s - rpn_cls: 0.0440 - rpn_regr: 0.0517 - detector_cls: 0.2919 - detector_regr: 0.1199Traceback (most recent call last):
#   File "train_frcnn.py", line 232, in <module>
#     loss_class = model_classifier.train_on_batch([X, X2[:, sel_samples, :]], [Y1[:, sel_samples, :], Y2[:, sel_samples, :]])
#   File "/usr/local/lib/python3.6/dist-packages/keras/engine/training.py", line 1621, in train_on_batch
#     outputs = self.train_function(ins)
#   File "/usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py", line 2103, in __call__
#     feed_dict=feed_dict)
#   File "/usr/local/lib/python3.6/dist-packages/tensorflow_core/python/client/session.py", line 956, in run
#     run_metadata_ptr)
#   File "/usr/local/lib/python3.6/dist-packages/tensorflow_core/python/client/session.py", line 1180, in _run
#     feed_dict_tensor, options, run_metadata)
#   File "/usr/local/lib/python3.6/dist-packages/tensorflow_core/python/client/session.py", line 1359, in _do_run
#     run_metadata)
#   File "/usr/local/lib/python3.6/dist-packages/tensorflow_core/python/client/session.py", line 1365, in _do_call
#     return fn(*args)
#   File "/usr/local/lib/python3.6/dist-packages/tensorflow_core/python/client/session.py", line 1350, in _run_fn
#     target_list, run_metadata)
#   File "/usr/local/lib/python3.6/dist-packages/tensorflow_core/python/client/session.py", line 1443, in _call_tf_sessionrun
#     run_metadata)
# KeyboardInterrupt
