# %% [markdown]
# <a href="https://colab.research.google.com/github/fambargh/SAMPLE/blob/master/Untitledod1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
pip install h5py

# %%
# importing required libraries
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
from matplotlib import patches

# %%
# !apt install -y caffe-cuda
# Out:
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# The following additional packages will be installed:
#   caffe-tools-cuda cython3 fonts-lyx javascript-common libblosc1
#   libcaffe-cuda1 libcublas9.1 libcudart9.1 libcurand9.1 libgflags2.2
#   libgoogle-glog0v5 libjs-jquery-ui libleveldb1v5 liblmdb0
#   python-matplotlib-data python-tables-data python3-bs4 python3-caffe-cuda
#   python3-chardet python3-cycler python3-dateutil python3-decorator
#   python3-gflags python3-h5py python3-html5lib python3-ipython
#   python3-ipython-genutils python3-leveldb python3-lxml python3-matplotlib
#   python3-networkx python3-nose python3-numexpr python3-olefile python3-pandas
#   python3-pandas-lib python3-pexpect python3-pickleshare python3-pil
#   python3-pkg-resources python3-prompt-toolkit python3-protobuf
#   python3-ptyprocess python3-pygments python3-pyparsing python3-pywt
#   python3-scipy python3-simplegeneric python3-six python3-skimage
# ...

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3Aietf%3Awg%3Aoauth%3A2.0%3Aoob&scope=email%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdocs.test%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive.photos.readonly%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fpeopleapi.readonly&response_type=code
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %%
c='/content/drive/My Drive/origalnorma/train1_labels.csv'

# %%
# read the csv file using read_csv function of pandas
train = pd.read_csv(c)
train.head()
# Out:
#            filename class_type  xmin  xmax  ymin  ymax
# 0  Im0043_ORIGA.jpg         od  1090  1934   670  1373
# 1  Im0044_ORIGA.jpg         od  1606  2300   680  1302
# 2  Im0045_ORIGA.jpg         od  1053  1868   667  1395
# 3  Im0046_ORIGA.jpg         od  1034  1850   698  1386
# 4  Im0047_ORIGA.jpg         od  1084  1878   736  1414

# %%
d='/content/drive/My Drive/origalnorma/train/Im0043_ORIGA.jpg'

# %%
# reading single image using imread function of matplotlib
image = plt.imread(d)
plt.imshow(image)

# %%
# Number of unique training images
train['filename'].nunique()
# Out:
# 440

# %%
# Number of classes
train['class_type'].value_counts()
# Out:
# od    440
# Name: class_type, dtype: int64

# %%
fig = plt.figure()

#add axes to the image
ax = fig.add_axes([0,0,1,1])

# read and plot the image
image = plt.imread(d)
plt.imshow(image)

# iterating over the image for different objects
for _,row in train[train.filename == 'Im0043_ORIGA.jpg'].iterrows():
    xmin = row.xmin
    xmax = row.xmax
    ymin = row.ymin
    ymax = row.ymax
    
    width = xmax - xmin
    height = ymax - ymin
    
    # assign different color to different classes of objects
    if row.class_type == 'od':
        edgecolor = 'r'
        ax.annotate('od', xy=(xmax-40,ymin+20))
        
    # add bounding boxes to the image
    rect = patches.Rectangle((xmin,ymin), width, height, edgecolor = edgecolor, facecolor = 'none')
    
    ax.add_patch(rect)

# %%
# !git clone https://github.com/kbardool/keras-frcnn.git
# Out:
# Cloning into 'keras-frcnn'...
# remote: Enumerating objects: 589, done.
# remote: Total 589 (delta 0), reused 0 (delta 0), pack-reused 589
# Receiving objects: 100% (589/589), 173.38 KiB | 326.00 KiB/s, done.
# Resolving deltas: 100% (402/402), done.

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).

# %%
! ls
# Out:
# drive  gdrive  keras-frcnn  sample_data

# %%
# %cd gdrive/My Drive/project folder
# Out:
# /content/gdrive/My Drive/project folder

# %%
! git clone https://github.com/kbardool/keras-frcnn.git
# Out:
# Cloning into 'keras-frcnn'...
# remote: Enumerating objects: 589, done.
# remote: Total 589 (delta 0), reused 0 (delta 0), pack-reused 589
# Receiving objects: 100% (589/589), 173.38 KiB | 317.00 KiB/s, done.
# Resolving deltas: 100% (402/402), done.

# %%
! pip install <desired-python-library>
# Out:
# /bin/bash: -c: line 0: syntax error near unexpected token `newline'
# /bin/bash: -c: line 0: ` pip install <desired-python-library>'

# %%
! python <executable_file.py>
# Out:
# /bin/bash: -c: line 0: syntax error near unexpected token `newline'
# /bin/bash: -c: line 0: ` python <executable_file.py>'

# %%
from utilities.file_handling import *
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-34-27fac3a0c788> in <module>()
# ----> 1 from utilities.file_handling import *
#
# ModuleNotFoundError: No module named 'utilities'
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------

# %%
from google.colab import drive
drive.mount(‘/content/gdrive’)
# %cd gdrive/My Drive/project_folder/cloned_repo_folder
! git pull

# %%
e='/content/drive/My Drive/project folder/datasets/train'

# %%
data = pd.DataFrame()
data['format'] = train['filename']

# as the images are in train_images folder, add train_images before the image name
for i in range(data.shape[0]):
    data['format'][i] = 'train/' + data['format'][i]

# add xmin, ymin, xmax, ymax and class as per the format required
for i in range(data.shape[0]):
    data['format'][i] = data['format'][i] + ',' + str(train['xmin'][i]) + ',' + str(train['ymin'][i]) + ',' + str(train['xmax'][i]) + ',' + str(train['ymax'][i]) + ',' + train['class_type'][i]

data.to_csv('annotate.txt', header=None, index=None, sep=' ')

# %%
# !pip install q keras==2.0.3
# Out:
# ...
#      |████████████████████████████████| 204kB 3.9MB/s
# ...
#   Created wheel for keras: filename=Keras-2.0.3-cp36-none-any.whl size=232964 sha256=fb633a31649c6075b0aa51525229045b1b0fd3836ee108c0488493e179233456
#   Stored in directory: /root/.cache/pip/wheels/a6/fb/de/faea9e49d563a35f198c6dede7f9260074b5beb8f9bffaaaa1
# Successfully built keras
# ERROR: textgenrnn 1.4.1 has requirement keras>=2.1.5, but you'll have keras 2.0.3 which is incompatible.
# ...
#   Found existing installation: Keras 2.2.5
#     Uninstalling Keras-2.2.5:
#       Successfully uninstalled Keras-2.2.5
# ...

# %%
# %cd keras-frcnn
# !python train_frcnn.py -o simple -p annotate.txt
# Out:
# [Errno 2] No such file or directory: 'keras-frcnn'
# /content/gdrive/My Drive/project folder/keras-frcnn
# Using TensorFlow backend.
# Traceback (most recent call last):
#   File "train_frcnn.py", line 79, in <module>
#     all_imgs, classes_count, class_mapping = get_data(options.train_path)
#   File "/content/gdrive/My Drive/project folder/keras-frcnn/keras_frcnn/simple_parser.py", line 14, in get_data
#     with open(input_path,'r') as f:
# FileNotFoundError: [Errno 2] No such file or directory: 'annotate.txt'
