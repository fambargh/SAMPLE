# %% [markdown]
# <a href="https://colab.research.google.com/github/fambargh/SAMPLE/blob/master/crop_with_download_use_premodel.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#clone the repo executed in 10.108 s
# !git clone https://github.com/kbardool/keras-frcnn.git
# Out:
# Cloning into 'keras-frcnn'...
# remote: Enumerating objects: 589, done.
# remote: Total 589 (delta 0), reused 0 (delta 0), pack-reused 589
# Receiving objects: 100% (589/589), 173.38 KiB | 322.00 KiB/s, done.
# Resolving deltas: 100% (402/402), done.

# %%
cd keras-frcnn
# Out:
# [Errno 2] No such file or directory: 'keras-frcnn'
# /content/keras-frcnn

# %%
# !pip install -r requirements.txt
# Out:
# ...
#      |████████████████████████████████| 204kB 2.3MB/s
# ...
#   Created wheel for Keras: filename=Keras-2.0.3-cp36-none-any.whl size=232964 sha256=02998ff0249ace32cf1d3bf7e269643cdd7c87a28d7abebce906b7e040e0483f
#   Stored in directory: /root/.cache/pip/wheels/a6/fb/de/faea9e49d563a35f198c6dede7f9260074b5beb8f9bffaaaa1
# Successfully built Keras
# ERROR: textgenrnn 1.4.1 has requirement keras>=2.1.5, but you'll have keras 2.0.3 which is incompatible.
# ...
#   Found existing installation: Keras 2.2.5
#     Uninstalling Keras-2.2.5:
#       Successfully uninstalled Keras-2.2.5
# ...

# %%
from google.colab import files
files.upload()
# Out:
#      <input type="file" id="files-f871e804-15a2-4f12-a815-fd67ea93191c" name="files[]" multiple disabled />
#      <output id="result-f871e804-15a2-4f12-a815-fd67ea93191c">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving model_frcnn.hdf5 to model_frcnn.hdf5

# %%
from google.colab import files
files.upload()
# Out:
#      <input type="file" id="files-1905e878-9615-457a-a94b-a503314fb863" name="files[]" multiple disabled />
#      <output id="result-1905e878-9615-457a-a94b-a503314fb863">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving config.pickle to config.pickle
# ...

# %%
rm -rf test_frcnn.py

# %%
from google.colab import files
files.upload()
# Out:
#      <input type="file" id="files-c64c1340-7a55-46df-8757-f6be7d64e8b8" name="files[]" multiple disabled />
#      <output id="result-c64c1340-7a55-46df-8757-f6be7d64e8b8">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving test_frcnn1.py to test_frcnn1.py
# ...

# %%
from google.colab import files
files.upload()
# Out:
#      <input type="file" id="files-9e5f1cd0-80a1-4d46-96ef-4e16bf801977" name="files[]" multiple disabled />
#      <output id="result-9e5f1cd0-80a1-4d46-96ef-4e16bf801977">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving origa128.zip to origa128.zip
# ...

# %%
from zipfile import ZipFile
filename = "origa500.zip"

with ZipFile(filename,'r') as zip:
  zip.extractall()
  print('Done')
# Out:
# Done

# %%
from google.colab import files
files.upload()
# Out:
#      <input type="file" id="files-82be3505-7c28-4095-93a0-72b4c42ea1b8" name="files[]" multiple disabled />
#      <output id="result-82be3505-7c28-4095-93a0-72b4c42ea1b8">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving resault1.zip to resault1.zip
# {'resault1.zip': b"PK\x03\x04\n\x00\x00\x00\x00\x00\xd6U|O\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\t\x00\x00\x00resault1/PK\x01\x02\x14\x00\n\x00\x00\x00\x00\x00\xd6U|O\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\t\x00\x00\x00\x00\x00\x00\x00\x00\x00\x10\x00\x00\x00\x00\x00\x00\x00resault1/PK\x05\x06\x00\x00\x00\x00\x01\x00\x01\x007\x00\x00\x00'\x00\x00\x00\x00\x00"}

# %%
from zipfile import ZipFile
filename = "resault1.zip"

with ZipFile(filename,'r') as zip:
  zip.extractall()
  print('Done')
# Out:
# Done

# %%
from google.colab import files
files.upload()
# Out:
#      <input type="file" id="files-0ee8ddd2-13d5-4c70-a4cb-03c36a1fdbc5" name="files[]" multiple disabled />
#      <output id="result-0ee8ddd2-13d5-4c70-a4cb-03c36a1fdbc5">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving resault2.zip to resault2.zip
# {'resault2.zip': b"PK\x03\x04\n\x00\x00\x00\x00\x00\xdaU|O\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\t\x00\x00\x00resault2/PK\x01\x02\x14\x00\n\x00\x00\x00\x00\x00\xdaU|O\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\t\x00\x00\x00\x00\x00\x00\x00\x00\x00\x10\x00\x00\x00\x00\x00\x00\x00resault2/PK\x05\x06\x00\x00\x00\x00\x01\x00\x01\x007\x00\x00\x00'\x00\x00\x00\x00\x00"}

# %%
from zipfile import ZipFile
filename = "resault2.zip"

with ZipFile(filename,'r') as zip:
  zip.extractall()
  print('Done')
# Out:
# Done

# %%
# test process executed in 35.301 s
# !python test_frcnn1.py -p origa500
# Out:
# Using TensorFlow backend.
# {0: 'od', 1: 'bg'}
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:47: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:351: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:3176: The name tf.random_uniform is deprecated. Please use tf.random.uniform instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:3043: The name tf.nn.max_pool is deprecated. Please use tf.nn.max_pool2d instead.
#
# ...

# %%
# !zip -r /content/keras-frcnn/file.zip /content/keras-frcnn/resault1
# Out:
# updating: content/keras-frcnn/resault1/ (stored 0%)
# updating: content/keras-frcnn/resault1/Im0563_g_ORIGA.png (deflated 3%)
# updating: content/keras-frcnn/resault1/Im0538_g_ORIGA.png (deflated 1%)
# updating: content/keras-frcnn/resault1/Im0573_g_ORIGA.png (deflated 2%)
# updating: content/keras-frcnn/resault1/Im0508_g_ORIGA.png (deflated 1%)
# updating: content/keras-frcnn/resault1/Im0548_g_ORIGA.png (deflated 1%)
# updating: content/keras-frcnn/resault1/Im0578_g_ORIGA.png (deflated 2%)
# updating: content/keras-frcnn/resault1/Im0598_g_ORIGA.png (deflated 3%)
# updating: content/keras-frcnn/resault1/Im0493_g_ORIGA.png (deflated 2%)
# updating: content/keras-frcnn/resault1/Im0558_g_ORIGA.png (deflated 1%)
# updating: content/keras-frcnn/resault1/Im0503_g_ORIGA.png (deflated 2%)
# updating: content/keras-frcnn/resault1/Im0001_ORIGA.png (deflated 2%)
# updating: content/keras-frcnn/resault1/Im0593_g_ORIGA.png (deflated 2%)
# ...

# %%
cd /content/keras-frcnn
# Out:
# /content/keras-frcnn

# %%
files.download("file.zip")

# %%
# !zip -r /content/keras-frcnn/resault2.zip /content/keras-frcnn/resault2
# Out:
#   adding: content/keras-frcnn/resault2/ (stored 0%)
#   adding: content/keras-frcnn/resault2/Im0563_g_ORIGA.png (deflated 1%)
#   adding: content/keras-frcnn/resault2/Im0538_g_ORIGA.png (deflated 1%)
#   adding: content/keras-frcnn/resault2/Im0573_g_ORIGA.png (deflated 1%)
#   adding: content/keras-frcnn/resault2/Im0508_g_ORIGA.png (deflated 1%)
#   adding: content/keras-frcnn/resault2/Im0548_g_ORIGA.png (deflated 2%)
#   adding: content/keras-frcnn/resault2/Im0578_g_ORIGA.png (deflated 2%)
#   adding: content/keras-frcnn/resault2/Im0598_g_ORIGA.png (deflated 1%)
#   adding: content/keras-frcnn/resault2/Im0493_g_ORIGA.png (deflated 1%)
#   adding: content/keras-frcnn/resault2/Im0558_g_ORIGA.png (deflated 1%)
#   adding: content/keras-frcnn/resault2/Im0503_g_ORIGA.png (deflated 1%)
#   adding: content/keras-frcnn/resault2/Im0001_ORIGA.png (deflated 1%)
#   adding: content/keras-frcnn/resault2/Im0593_g_ORIGA.png (deflated 2%)
# ...

# %%
files.download("resault2.zip")
