# %% [markdown]
# <a href="https://colab.research.google.com/github/fambargh/SAMPLE/blob/master/od_detection.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
pip install h5py

# %%
# !pip install  keras==2.0.3
# Out:
# ...
#      |████████████████████████████████| 204kB 4.9MB/s
# ...
#   Created wheel for keras: filename=Keras-2.0.3-cp36-none-any.whl size=232964 sha256=bc1ee82ed56c41c88e0595b122ea51468c7269992b4f2c53d58240195d3a9106
#   Stored in directory: /root/.cache/pip/wheels/a6/fb/de/faea9e49d563a35f198c6dede7f9260074b5beb8f9bffaaaa1
# Successfully built keras
# ERROR: textgenrnn 1.4.1 has requirement keras>=2.1.5, but you'll have keras 2.0.3 which is incompatible.
# ...
#   Found existing installation: Keras 2.2.5
#     Uninstalling Keras-2.2.5:
#       Successfully uninstalled Keras-2.2.5
# ...

# %%
# importing required libraries
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
from matplotlib import patches

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
c='/content/drive/My Drive/fm/blood/train.csv'

# %%
# read the csv file using read_csv function of pandas
train = pd.read_csv(c)
train.head()
# Out:
#             image_names cell_type  xmin  xmax  ymin  ymax
# 0  BloodImage_00111.jpg       RBC   458   571   198   296
# 1  BloodImage_00111.jpg       RBC   405   518   240   338
# 2  BloodImage_00111.jpg       RBC   365   478    40   138
# 3  BloodImage_00111.jpg       RBC   512   630    75   188
# 4  BloodImage_00111.jpg       RBC   468   570    71   175

# %%
fig = plt.figure()

#add axes to the image
ax = fig.add_axes([0,0,1,1])

# read and plot the image
image = plt.imread('/content/drive/My Drive/fm/blood/train_images/BloodImage_00111.jpg')
plt.imshow(image)

# iterating over the image for different objects
for _,row in train[train.image_names == "BloodImage_00111.jpg"].iterrows():
    xmin = row.xmin
    xmax = row.xmax
    ymin = row.ymin
    ymax = row.ymax
    
    width = xmax - xmin
    height = ymax - ymin
    
    # assign different color to different classes of objects
    if row.cell_type == 'RBC':
        edgecolor = 'r'
        ax.annotate('RBC', xy=(xmax-40,ymin+20))
    elif row.cell_type == 'WBC':
        edgecolor = 'b'
        ax.annotate('WBC', xy=(xmax-40,ymin+20))
    elif row.cell_type == 'Platelets':
        edgecolor = 'g'
        ax.annotate('Platelets', xy=(xmax-40,ymin+20))
        
    # add bounding boxes to the image
    rect = patches.Rectangle((xmin,ymin), width, height, edgecolor = edgecolor, facecolor = 'none')
    
    ax.add_patch(rect)

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
! ls
# Out:
# shell-init: error retrieving current directory: getcwd: cannot access parent directories: Transport endpoint is not connected
# ls: cannot open directory '.': Transport endpoint is not connected

# %%
# %cd gdrive/My Drive/fm
# Out:
# ERROR:root:Internal Python error in the inspect module.
# Below is the traceback from this internal error.
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.6/dist-packages/IPython/core/interactiveshell.py", line 2882, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "<ipython-input-45-5f89e2778668>", line 1, in <module>
#     get_ipython().magic('cd gdrive/My Drive/fm')
#   File "/usr/local/lib/python3.6/dist-packages/IPython/core/interactiveshell.py", line 2160, in magic
#     return self.run_line_magic(magic_name, magic_arg_s)
#   File "/usr/local/lib/python3.6/dist-packages/IPython/core/interactiveshell.py", line 2081, in run_line_magic
#     result = fn(*args,**kwargs)
#   File "</usr/local/lib/python3.6/dist-packages/decorator.py:decorator-gen-91>", line 2, in cd
#   File "/usr/local/lib/python3.6/dist-packages/IPython/core/magic.py", line 188, in <lambda>
#     call = lambda f, *a, **k: f(*a, **k)
# ...

# %%
! git clone https://github.com/kbardool/keras-frcnn.git
# Out:
# shell-init: error retrieving current directory: getcwd: cannot access parent directories: Transport endpoint is not connected
# fatal: could not create work tree dir 'keras-frcnn': Transport endpoint is not connected

# %%
! pip install <desired-python-library>
# Out:
# shell-init: error retrieving current directory: getcwd: cannot access parent directories: Transport endpoint is not connected
# /bin/bash: -c: line 0: syntax error near unexpected token `newline'
# /bin/bash: -c: line 0: ` pip install <desired-python-library>'

# %%
! python <executable_file.py>
# Out:
# shell-init: error retrieving current directory: getcwd: cannot access parent directories: Transport endpoint is not connected
# /bin/bash: -c: line 0: syntax error near unexpected token `newline'
# /bin/bash: -c: line 0: ` python <executable_file.py>'

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# %cd gdrive/My Drive/proje/cloned_repo_folder
! git pull
# Out:
# ERROR:root:Internal Python error in the inspect module.
# Below is the traceback from this internal error.
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.6/dist-packages/IPython/core/interactiveshell.py", line 2882, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "<ipython-input-49-959cb81c5557>", line 3, in <module>
#     get_ipython().magic('cd gdrive/My Drive/proje/cloned_repo_folder')
#   File "/usr/local/lib/python3.6/dist-packages/IPython/core/interactiveshell.py", line 2160, in magic
#     return self.run_line_magic(magic_name, magic_arg_s)
#   File "/usr/local/lib/python3.6/dist-packages/IPython/core/interactiveshell.py", line 2081, in run_line_magic
#     result = fn(*args,**kwargs)
#   File "</usr/local/lib/python3.6/dist-packages/decorator.py:decorator-gen-91>", line 2, in cd
# ...

# %%
data = pd.DataFrame()
data['format'] = train['image_names']

# as the images are in train_images folder, add train_images before the image name
for i in range(data.shape[0]):
    data['format'][i] = '/content/drive/My Drive/fm/blood/train_images/' + data['format'][i]

# add xmin, ymin, xmax, ymax and class as per the format required
for i in range(data.shape[0]):
    data['format'][i] = data['format'][i] + ',' + str(train['xmin'][i]) + ',' + str(train['ymin'][i]) + ',' + str(train['xmax'][i]) + ',' + str(train['ymax'][i]) + ',' + train['cell_type'][i]

data.to_csv('annotate.txt', header=None, index=None, sep=' ')
# Out:
# ERROR:root:Internal Python error in the inspect module.
# Below is the traceback from this internal error.
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.6/dist-packages/IPython/core/interactiveshell.py", line 2882, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "<ipython-input-50-b1bcd009fd97>", line 12, in <module>
#     data.to_csv('annotate.txt', header=None, index=None, sep=' ')
#   File "/usr/local/lib/python3.6/dist-packages/pandas/core/generic.py", line 3228, in to_csv
#     formatter.save()
#   File "/usr/local/lib/python3.6/dist-packages/pandas/io/formats/csvs.py", line 183, in save
#     compression=self.compression,
#   File "/usr/local/lib/python3.6/dist-packages/pandas/io/common.py", line 332, in _get_handle
#     from s3fs import S3File
#   File "<frozen importlib._bootstrap>", line 971, in _find_and_load
#   File "<frozen importlib._bootstrap>", line 951, in _find_and_load_unlocked
# ...

# %%
input_path='/content/drive/My Drive/fm/annotate.txt'

# %%
# %cd keras-frcnn
! python train_frcnn.py -o simple -p annotate.txt
# Out:
# ERROR:root:Internal Python error in the inspect module.
# Below is the traceback from this internal error.
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.6/dist-packages/IPython/core/interactiveshell.py", line 2882, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "<ipython-input-52-1a803bb8a0e4>", line 1, in <module>
#     get_ipython().magic('cd keras-frcnn')
#   File "/usr/local/lib/python3.6/dist-packages/IPython/core/interactiveshell.py", line 2160, in magic
#     return self.run_line_magic(magic_name, magic_arg_s)
#   File "/usr/local/lib/python3.6/dist-packages/IPython/core/interactiveshell.py", line 2081, in run_line_magic
#     result = fn(*args,**kwargs)
#   File "</usr/local/lib/python3.6/dist-packages/decorator.py:decorator-gen-91>", line 2, in cd
#   File "/usr/local/lib/python3.6/dist-packages/IPython/core/magic.py", line 188, in <lambda>
#     call = lambda f, *a, **k: f(*a, **k)
# ...

# %%
import cv2
import numpy as np

#def get_data(input_path):
found_bg = False
all_imgs = {}

classes_count = {}

class_mapping = {}

visualise = True
	
with open(input_path,'r') as f:
  
  print('Parsing annotation files')
  
  for line in f:
    line_split = line.strip().split(',')
    (filename,x1,y1,x2,y2,class_name) = line_split
    
    if class_name not in classes_count:
      classes_count[class_name] = 1
    else:
      classes_count[class_name] += 1
      
    if class_name not in class_mapping:
      if class_name == 'bg' and found_bg == False:
        print('Found class name with special name bg. Will be treated as a background region (this is usually for hard negative mining).')
        found_bg = True
        class_mapping[class_name] = len(class_mapping)

    if filename not in all_imgs:
     all_imgs[filename] = {}
     
     img = cv2.imread(filename)
     (rows,cols) = img.shape[:2]
     all_imgs[filename]['filepath'] = filename
     all_imgs[filename]['width'] = cols
     all_imgs[filename]['height'] = rows
     all_imgs[filename]['bboxes'] = []
     if np.random.randint(0,6) > 0:
       all_imgs[filename]['imageset'] = 'trainval'
    else:
      all_imgs[filename]['imageset'] = 'test'
      
    all_imgs[filename]['bboxes'].append({'class': class_name, 'x1': int(x1), 'x2': int(x2), 'y1': int(y1), 'y2': int(y2)})
      
all_data = []
for key in all_imgs:
  all_data.append(all_imgs[key])
		
		# make sure the bg class is last in the list
if found_bg:
  if class_mapping['bg'] != len(class_mapping) - 1:
    key_to_switch = [key for key in class_mapping.keys() if class_mapping[key] == len(class_mapping)-1][0]
    val_to_switch = class_mapping['bg']
    class_mapping['bg'] = len(class_mapping) - 1
    class_mapping[key_to_switch] = val_to_switch
		
		#return all_data, classes_count, class_mapping
# Out:
# ERROR:root:Internal Python error in the inspect module.
# Below is the traceback from this internal error.
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.6/dist-packages/IPython/core/interactiveshell.py", line 2882, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "<ipython-input-53-c0a297f76836>", line 14, in <module>
#     with open(input_path,'r') as f:
# OSError: [Errno 107] Transport endpoint is not connected: '/content/drive/My Drive/fm/annotate.txt'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.6/dist-packages/IPython/core/interactiveshell.py", line 1823, in showtraceback
#     stb = value._render_traceback_()
# AttributeError: 'OSError' object has no attribute '_render_traceback_'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
# ...
