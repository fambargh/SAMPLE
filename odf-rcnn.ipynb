# %% [markdown]
# <a href="https://colab.research.google.com/github/fambargh/SAMPLE/blob/master/odf-rcnn.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#clone the repo executed in 10.108 s
# !git clone https://github.com/kbardool/keras-frcnn.git
# Out:
# Cloning into 'keras-frcnn'...
# remote: Enumerating objects: 589, done.
# remote: Total 589 (delta 0), reused 0 (delta 0), pack-reused 589
# Receiving objects: 100% (589/589), 173.38 KiB | 319.00 KiB/s, done.
# Resolving deltas: 100% (402/402), done.

# %%
#generate the path for work
cd keras-frcnn
# Out:
# [Errno 2] No such file or directory: 'keras-frcnn'
# /content/keras-frcnn

# %%
#what is in the path?
# !ls
# Out:
# keras_frcnn  measure_map.py  requirements.txt  train_frcnn.py
# LICENSE      README.md	     test_frcnn.py     train_images.zip

# %%
#first upload train.csv file then upload train.zip and unzip it and finally upload train_frcnn.py 
#after removing preveuos version named train_frcnn.py...
from google.colab import files
files.upload()

# %%
from google.colab import files
files.upload()

# %%
from zipfile import ZipFile
filename = "train_images.zip"

with ZipFile(filename,'r') as zip:
  zip.extractall()
  print('Done')
# Out:
# Done

# %%
# !rm -rf train_frcnn.py

# %%
# !rm -rf train_images.zip

# %%
# !ls
# Out:
# keras_frcnn  measure_map.py  requirements.txt  train.csv
# LICENSE      README.md	     test_frcnn.py     train_images

# %%
from google.colab import files
files.upload()

# %%
# !pip install -r requirements.txt
# Out:
# ...
#      |████████████████████████████████| 204kB 2.7MB/s
# ...
#   Created wheel for Keras: filename=Keras-2.0.3-cp36-none-any.whl size=232964 sha256=1510b4ecc945ec3e177590220a354d225f785e30c60122928782915661d5e007
#   Stored in directory: /root/.cache/pip/wheels/a6/fb/de/faea9e49d563a35f198c6dede7f9260074b5beb8f9bffaaaa1
# Successfully built Keras
# ERROR: textgenrnn 1.4.1 has requirement keras>=2.1.5, but you'll have keras 2.0.3 which is incompatible.
# ...
#   Found existing installation: Keras 2.2.5
#     Uninstalling Keras-2.2.5:
#       Successfully uninstalled Keras-2.2.5
# ...

# %%
cd /content/keras-frcnn
# Out:
# /content/keras-frcnn

# %%
# !pwd
# Out:
# /content/keras-frcnn

# %%
cd /content/keras-frcnn
# Out:
# /content/keras-frcnn

# %%
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
from matplotlib import patches

# %%
train = pd.read_csv('/content/keras-frcnn/train.csv')
train.head()
# Out:
#         image_names cell_type  xmin  xmax  ymin  ymax
# 0  Im0043_ORIGA.jpg        od    46    84    44    83
# 1  Im0044_ORIGA.jpg        od    65    98    42    78
# 2  Im0045_ORIGA.jpg        od    39    84    41    89
# 3  Im0046_ORIGA.jpg        od    41    80    43    86
# 4  Im0047_ORIGA.jpg        od    45    81    47    85

# %%
data = pd.DataFrame()
data['format'] = train['image_names']

# as the images are in train_images folder, add train_images before the image name
for i in range(data.shape[0]):
    data['format'][i] = '/content/keras-frcnn/train_images/' + data['format'][i]

# add xmin, ymin, xmax, ymax and class as per the format required
for i in range(data.shape[0]):
    data['format'][i] = data['format'][i] + ',' + str(train['xmin'][i]) + ',' + str(train['ymin'][i]) + ',' + str(train['xmax'][i]) + ',' + str(train['ymax'][i]) + ',' + train['cell_type'][i]

data.to_csv('annotate.txt', header=None, index=None, sep=' ')

# %%
cd /content/keras-frcnn
# Out:
# /content/keras-frcnn

# %%
# the training process executed in 15145.674 s. 4.20min
# !python train_frcnn.py -o simple -p 'annotate.txt'
# Out:
# Using TensorFlow backend.
# Parsing annotation files
# Training images per class:
# {'bg': 0, 'od': 440}
# Num classes (including bg) = 2
# Config has been written to config.pickle, and can be loaded when testing to ensure correct results
# Num train samples 362
# Num val samples 78
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:47: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:351: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:3176: The name tf.random_uniform is deprecated. Please use tf.random.uniform instead.
#
# ...

# %%
model_all.save_weights('my_model_weights.h5')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-52-4f29406203aa> in <module>()
# ----> 1 model_all.save_weights('my_model_weights.h5')
#
# NameError: name 'model_all' is not defined

# %%
#upload resault folder from local to save the result of test_image then upload
# the test image and finally upload test_frcnn.py after removing previuos version.
from google.colab import files
files.upload()

# %%
from zipfile import ZipFile
filename = "resault.zip"

with ZipFile(filename,'r') as zip:
  zip.extractall()
  print('Done')
# Out:
# Done

# %%
# test process executed in 35.301 s
# !python test_frcnn.py -p test_images
# Out:
# Using TensorFlow backend.
# {0: 'od', 1: 'bg'}
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:47: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:351: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:3176: The name tf.random_uniform is deprecated. Please use tf.random.uniform instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:3043: The name tf.nn.max_pool is deprecated. Please use tf.nn.max_pool2d instead.
#
# ...

# %%
rm -rf test_images

# %%
#go to this dir for downloading the resault
# %cd /content/keras-frcnn/resault
# Out:
# /content/keras-frcnn/resault

# %%
# !ls
# Out:
# 0.png	14.png	19.png	23.png	28.png	32.png	37.png	41.png	8.png
# 10.png	15.png	1.png	24.png	29.png	33.png	38.png	4.png	9.png
# 11.png	16.png	20.png	25.png	2.png	34.png	39.png	5.png
# 12.png	17.png	21.png	26.png	30.png	35.png	3.png	6.png
# 13.png	18.png	22.png	27.png	31.png	36.png	40.png	7.png

# %%
#download from colab to local
for i in range(0,42):
  files.download('{}.png'.format(i))
