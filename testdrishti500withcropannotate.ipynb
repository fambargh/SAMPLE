# %% [markdown]
# <a href="https://colab.research.google.com/github/fambargh/SAMPLE/blob/master/testdrishti500withcropannotate.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !git clone https://github.com/kbardool/keras-frcnn.git
# Out:
# Cloning into 'keras-frcnn'...
# remote: Enumerating objects: 589, done.
# remote: Total 589 (delta 0), reused 0 (delta 0), pack-reused 589
# Receiving objects: 100% (589/589), 173.38 KiB | 333.00 KiB/s, done.
# Resolving deltas: 100% (402/402), done.

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %%
cd /content/keras-frcnn
# Out:
# /content/keras-frcnn

# %%
from zipfile import ZipFile
filename = "drishti.zip"

with ZipFile(filename,'r') as zip:
  zip.extractall()
  print('Done')
# Out:
# Done

# %%
from google.colab import files
files.upload()
# Out:
#      <input type="file" id="files-b3a1826c-7770-43bf-9c8a-2355afde2db8" name="files[]" multiple disabled />
#      <output id="result-b3a1826c-7770-43bf-9c8a-2355afde2db8">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving resault1.zip to resault1.zip
# {'resault1.zip': b"PK\x03\x04\n\x00\x00\x00\x00\x00\xd6U|O\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\t\x00\x00\x00resault1/PK\x01\x02\x14\x00\n\x00\x00\x00\x00\x00\xd6U|O\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\t\x00\x00\x00\x00\x00\x00\x00\x00\x00\x10\x00\x00\x00\x00\x00\x00\x00resault1/PK\x05\x06\x00\x00\x00\x00\x01\x00\x01\x007\x00\x00\x00'\x00\x00\x00\x00\x00"}

# %%
from zipfile import ZipFile
filename = "resault1.zip"

with ZipFile(filename,'r') as zip:
  zip.extractall()
  print('Done')
# Out:
# Done

# %%
from google.colab import files
files.upload()
# Out:
#      <input type="file" id="files-287b9a67-8471-4a3d-b09c-ce66d57a1b95" name="files[]" multiple disabled />
#      <output id="result-287b9a67-8471-4a3d-b09c-ce66d57a1b95">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving resault2.zip to resault2.zip
# {'resault2.zip': b"PK\x03\x04\n\x00\x00\x00\x00\x00\xdaU|O\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\t\x00\x00\x00resault2/PK\x01\x02\x14\x00\n\x00\x00\x00\x00\x00\xdaU|O\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\t\x00\x00\x00\x00\x00\x00\x00\x00\x00\x10\x00\x00\x00\x00\x00\x00\x00resault2/PK\x05\x06\x00\x00\x00\x00\x01\x00\x01\x007\x00\x00\x00'\x00\x00\x00\x00\x00"}

# %%
from zipfile import ZipFile
filename = "resault2.zip"

with ZipFile(filename,'r') as zip:
  zip.extractall()
  print('Done')
# Out:
# Done

# %%
# !pip install -r requirements.txt
# Out:
# ...
#      |████████████████████████████████| 204kB 2.8MB/s
# ...
#   Created wheel for Keras: filename=Keras-2.0.3-cp36-none-any.whl size=232964 sha256=53513300a1c3f83fded450d11fedd1c840b672bf92aad1d9a5cd7a0aedad046f
#   Stored in directory: /root/.cache/pip/wheels/a6/fb/de/faea9e49d563a35f198c6dede7f9260074b5beb8f9bffaaaa1
# Successfully built Keras
# ERROR: textgenrnn 1.4.1 has requirement keras>=2.1.5, but you'll have keras 2.0.3 which is incompatible.
# ...
#   Found existing installation: Keras 2.2.5
#     Uninstalling Keras-2.2.5:
#       Successfully uninstalled Keras-2.2.5
# ...

# %%
cd /content/keras-frcnn
# Out:
# /content/keras-frcnn

# %%
from google.colab import files
files.upload()
# Out:
#      <input type="file" id="files-496d0dcf-db98-4b90-8ce0-1becdde38443" name="files[]" multiple disabled />
#      <output id="result-496d0dcf-db98-4b90-8ce0-1becdde38443">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving test_frcnn1 - Copy (4).py to test_frcnn1 - Copy (4).py
# ...

# %%
# test process executed in 35.301 s
# !python test_frcnn1.py -p drishti
# Out:
# Using TensorFlow backend.
# {0: 'od', 1: 'bg'}
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:47: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:351: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:3176: The name tf.random_uniform is deprecated. Please use tf.random.uniform instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:3043: The name tf.nn.max_pool is deprecated. Please use tf.nn.max_pool2d instead.
#
# ...

# %%
# !zip -r /content/keras-frcnn/drishti_result1 /content/keras-frcnn/resault1
# Out:
#   adding: content/keras-frcnn/resault1/ (stored 0%)
#   adding: content/keras-frcnn/resault1/drishtiGS_093.png (deflated 1%)
#   adding: content/keras-frcnn/resault1/drishtiGS_009.png (deflated 1%)
#   adding: content/keras-frcnn/resault1/drishtiGS_002.png (deflated 2%)
#   adding: content/keras-frcnn/resault1/drishtiGS_092.png (deflated 1%)
#   adding: content/keras-frcnn/resault1/drishtiGS_056.png (deflated 1%)
#   adding: content/keras-frcnn/resault1/drishtiGS_038.png (deflated 1%)
#   adding: content/keras-frcnn/resault1/drishtiGS_027.png (deflated 1%)
#   adding: content/keras-frcnn/resault1/drishtiGS_054.png (deflated 1%)
#   adding: content/keras-frcnn/resault1/drishtiGS_080.png (deflated 1%)
#   adding: content/keras-frcnn/resault1/drishtiGS_017.png (deflated 1%)
#   adding: content/keras-frcnn/resault1/drishtiGS_077.png (deflated 1%)
#   adding: content/keras-frcnn/resault1/drishtiGS_091.png (deflated 1%)
# ...

# %%
# !zip -r /content/keras-frcnn/drishti_result2 /content/keras-frcnn/resault2
# Out:
#   adding: content/keras-frcnn/resault2/ (stored 0%)
#   adding: content/keras-frcnn/resault2/drishtiGS_093.png (deflated 1%)
#   adding: content/keras-frcnn/resault2/drishtiGS_009.png (deflated 1%)
#   adding: content/keras-frcnn/resault2/drishtiGS_002.png (deflated 1%)
#   adding: content/keras-frcnn/resault2/drishtiGS_092.png (deflated 1%)
#   adding: content/keras-frcnn/resault2/drishtiGS_056.png (deflated 1%)
#   adding: content/keras-frcnn/resault2/drishtiGS_038.png (deflated 1%)
#   adding: content/keras-frcnn/resault2/drishtiGS_027.png (deflated 1%)
#   adding: content/keras-frcnn/resault2/drishtiGS_054.png (deflated 1%)
#   adding: content/keras-frcnn/resault2/drishtiGS_080.png (deflated 1%)
#   adding: content/keras-frcnn/resault2/drishtiGS_017.png (deflated 1%)
#   adding: content/keras-frcnn/resault2/drishtiGS_077.png (deflated 1%)
#   adding: content/keras-frcnn/resault2/drishtiGS_091.png (deflated 1%)
# ...
