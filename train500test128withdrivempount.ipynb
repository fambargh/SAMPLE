# %% [markdown]
# <a href="https://colab.research.google.com/github/fambargh/SAMPLE/blob/master/train500test128withdrivempount.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#clone the repo executed in 10.108 s
# !git clone https://github.com/kbardool/keras-frcnn.git
# Out:
# Cloning into 'keras-frcnn'...
# remote: Enumerating objects: 589, done.
# remote: Total 589 (delta 0), reused 0 (delta 0), pack-reused 589
# Receiving objects: 100% (589/589), 173.38 KiB | 768.00 KiB/s, done.
# Resolving deltas: 100% (402/402), done.

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %%
cd /content/keras-frcnn
# Out:
# /content/keras-frcnn

# %%
from zipfile import ZipFile
filename = "train500.zip"

with ZipFile(filename,'r') as zip:
  zip.extractall()
  print('Done')
# Out:
# Done

# %%
from zipfile import ZipFile
filename = "resault1.zip"

with ZipFile(filename,'r') as zip:
  zip.extractall()
  print('Done')
# Out:
# Done

# %%
from zipfile import ZipFile
filename = "resault2.zip"

with ZipFile(filename,'r') as zip:
  zip.extractall()
  print('Done')
# Out:
# Done

# %%
# !pip install -r requirements.txt
# Out:
# ...
#      |████████████████████████████████| 204kB 6.7MB/s
# ...
#   Created wheel for Keras: filename=Keras-2.0.3-cp36-none-any.whl size=232964 sha256=e2ea638ab318b206335c6e1b76970cd06686eb91a0101f15c881132b7c933a50
#   Stored in directory: /root/.cache/pip/wheels/a6/fb/de/faea9e49d563a35f198c6dede7f9260074b5beb8f9bffaaaa1
# Successfully built Keras
# ERROR: textgenrnn 1.4.1 has requirement keras>=2.1.5, but you'll have keras 2.0.3 which is incompatible.
# ...
#   Found existing installation: Keras 2.2.5
#     Uninstalling Keras-2.2.5:
#       Successfully uninstalled Keras-2.2.5
# ...

# %%
cd /content/keras-frcnn
# Out:
# /content/keras-frcnn

# %%
from google.colab import files
files.upload()
# Out:
#      <input type="file" id="files-81f3d4a1-0413-4b4b-a9de-7233033cb957" name="files[]" multiple disabled />
#      <output id="result-81f3d4a1-0413-4b4b-a9de-7233033cb957">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving model_frcnn.hdf5 to model_frcnn (1).hdf5

# %%
rm -rf test_frcnn1.py

# %%
from google.colab import files
files.upload()
# Out:
#      <input type="file" id="files-b36d699d-27d5-47a7-b43b-701c32c134ad" name="files[]" multiple disabled />
#      <output id="result-b36d699d-27d5-47a7-b43b-701c32c134ad">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving test_frcnn1.py to test_frcnn1.py
# ...

# %%
# test process executed in 35.301 s
# !python test_frcnn1.py -p train500
# Out:
# Using TensorFlow backend.
# {0: 'od', 1: 'bg'}
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:47: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:351: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:3176: The name tf.random_uniform is deprecated. Please use tf.random.uniform instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:3043: The name tf.nn.max_pool is deprecated. Please use tf.nn.max_pool2d instead.
#
# ...

# %%
# !zip -r /content/keras-frcnn/train500test1281.zip /content/keras-frcnn/resault1
# Out:
# updating: content/keras-frcnn/resault1/ (stored 0%)
# updating: content/keras-frcnn/resault1/Im0041_ORIGA.png (deflated 2%)
# updating: content/keras-frcnn/resault1/Im0329_ORIGA.png (deflated 2%)
# updating: content/keras-frcnn/resault1/Im0093_ORIGA.png (deflated 2%)
# updating: content/keras-frcnn/resault1/Im0073_ORIGA.png (deflated 2%)
# updating: content/keras-frcnn/resault1/drishtiGS_048.png (deflated 1%)
# updating: content/keras-frcnn/resault1/Im0164_ORIGA.png (deflated 2%)
# updating: content/keras-frcnn/resault1/Im0271_ORIGA.png (deflated 2%)
# updating: content/keras-frcnn/resault1/Im0340_ORIGA.png (deflated 1%)
# updating: content/keras-frcnn/resault1/Im0170_ORIGA.png (deflated 3%)
# updating: content/keras-frcnn/resault1/Im0094_ORIGA.png (deflated 2%)
# updating: content/keras-frcnn/resault1/Im0381_ORIGA.png (deflated 2%)
# updating: content/keras-frcnn/resault1/Im0067_ORIGA.png (deflated 2%)
# updating: content/keras-frcnn/resault1/Im0102_ORIGA.png (deflated 3%)
# ...

# %%
# !zip -r /content/keras-frcnn/train500test1282.zip /content/keras-frcnn/resault2
# Out:
#   adding: content/keras-frcnn/resault2/ (stored 0%)
#   adding: content/keras-frcnn/resault2/Im0041_ORIGA.png (deflated 1%)
#   adding: content/keras-frcnn/resault2/Im0329_ORIGA.png (deflated 2%)
#   adding: content/keras-frcnn/resault2/Im0093_ORIGA.png (deflated 2%)
#   adding: content/keras-frcnn/resault2/Im0073_ORIGA.png (deflated 2%)
#   adding: content/keras-frcnn/resault2/drishtiGS_048.png (deflated 1%)
#   adding: content/keras-frcnn/resault2/Im0164_ORIGA.png (deflated 1%)
#   adding: content/keras-frcnn/resault2/Im0271_ORIGA.png (deflated 2%)
#   adding: content/keras-frcnn/resault2/Im0340_ORIGA.png (deflated 1%)
#   adding: content/keras-frcnn/resault2/Im0170_ORIGA.png (deflated 1%)
#   adding: content/keras-frcnn/resault2/Im0094_ORIGA.png (deflated 1%)
#   adding: content/keras-frcnn/resault2/Im0381_ORIGA.png (deflated 1%)
#   adding: content/keras-frcnn/resault2/Im0067_ORIGA.png (deflated 1%)
#   adding: content/keras-frcnn/resault2/Im0102_ORIGA.png (deflated 1%)
# ...
